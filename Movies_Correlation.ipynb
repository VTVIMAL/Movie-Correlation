# %%
# Importing the libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

 #  plots/graphs will be displayed just below the cell where your plotting commands are written
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)


# Reading the data
df = pd.read_csv(r"C:\Users\vimal\Desktop\Projects\Data Anaysis\movies.csv")

# %%
# view the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# check missing values in columns

for col in df.columns:
    per_missing = np.mean(df[col].isnull())
    print(f"{col} :{per_missing:.2f}%")
# Out:
# name :0.00%
# rating :0.00%
# genre :0.00%
# year :0.00%
# released :0.00%
# score :0.00%
# votes :0.00%
# director :0.00%
# writer :0.00%
# star :0.00%
# country :0.00%
# budget :0.00%
# gross :0.00%
# company :0.00%
# runtime :0.00%

# %%
df = df.dropna()
#delete all the rows with missing data

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change datatype of columns

df["budget"] = df["budget"].astype("int64")

df["gross"] = df["gross"].astype("int64")

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# changing the irregularity between year and released(year)
# creating a yearcorrected with the correct year
df["yearcorrected"] = df["released"].str.extract(pat = '([0-9]{4})').astype(int)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
df = df.sort_values(by=["gross"], inplace=False, ascending=False)

# %%
pd.set_option("display.max_rows",None)  # display all the rows default is 20

# %%
# corelation

# %%
# sctterplot budget vs gross


plt.scatter(x = df['budget'], y = df['gross'])

plt.title("Budget VS Gross Income")
plt.xlabel("Budget for filim")
plt.ylabel("Gross Earnings")
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# plot budget vs gross using seaborn

sns.regplot(x="budget", y = "gross", data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#looking at correaltion
df.corr()
# Out:
#                    year     score     votes    budget     gross   runtime  \
# year           1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score          0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes          0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget         0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross          0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime        0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrected  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#                yearcorrected
# year                0.998726
# score               0.061923
# votes               0.203098
# budget              0.320312
# gross               0.268721
# runtime             0.075294
# yearcorrected       1.000000

# %%
# visualizing the correlation (df.corr)

correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %%
# Cheking Correlation between Company and Gross

# Convert company to a numeric value

df_numeric = df

for col_name in df_numeric.columns:
    if(df_numeric[col_name].dtype == "object"):
        df_numeric[col_name] = df_numeric[col_name].astype("category")  # convert evey object data type to catagory dtype
        df_numeric[col_name] = df_numeric[col_name].cat.codes  # assign different numeiric values for content
        
df_numeric.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrected
# 5445  1534       47  237000000  2847246203     1382    162.0           2009
# 7445  1470       47  356000000  2797501328      983    181.0           2019
# 3045  1073       47  200000000  2201647264     1382    194.0           1997
# 6663   356       47  245000000  2069521700      945    138.0           2015
# 7244  1470       47  321000000  2048359754      983    149.0           2018

# %%
correlation_matrix = df_numeric.corr()

sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix on Numeric Data")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %%
# observe data with highest correlation

corr_matrix = df_numeric.corr()

corr_pairs = corr_matrix.unstack()

sorted_pairs = corr_pairs.sort_values()

high_corr = sorted_pairs[(sorted_pairs) > 0.5 ]
high_corr
# Out:
# gross          votes            0.614751
# votes          gross            0.614751
# gross          budget           0.740247
# budget         gross            0.740247
# year           yearcorrected    0.998726
# yearcorrected  year             0.998726
# name           name             1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# writer         writer           1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# yearcorrected  yearcorrected    1.000000
# dtype: float64

# %%
# Finalized the observation that Votes and Budget has the high correlation to Gross Earnings
